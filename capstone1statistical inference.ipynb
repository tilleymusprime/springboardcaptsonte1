# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
from scipy.stats import normaltest

# %%
import seaborn as sns

# %%
df = pd.read_csv('C:\\Users\\tilleymusprime\\Desktop\\fdf_clean.csv')

# %%
dfcols = list(df.columns.values)

# %%
print(dfcols)
# Out:
# ['Overall Rating', 'Unnamed: 1', '3Cone', 'Acceleration', 'Agility', 'Awareness', 'Ball Carrier Vision', 'Bench', 'Block Shedding', 'Broad Jump', 'Carrying', 'Catch In Traffic', 'Catching', 'Elusiveness', 'Finesse Moves', 'Height', 'Hit Power', 'Impact Blocking', 'Injury', 'Juke Move', 'Jumping', 'Man Coverage', 'Pass Block', 'Play Action', 'Play Recognition', 'Position', 'Press', 'Pursuit', 'Release', 'Route Running', 'Run Block', 'Shuttle', 'Speed', 'Spin Move', 'Stamina', 'Stiff Arm', 'Strength', 'Tackle', 'Throw Accuracy Deep', 'Throw Accuracy Mid', 'Throw Accuracy Short', 'Throw Power', 'Throw on the Run', 'Toughness', 'Trucking', 'Unnamed: 0', 'Unnamed: 0_x', 'Vertical', 'Weight', 'Zone Coverage', '4AVG Speed', '3AVG Speed', '2AVG Speed', '4AVG Acceleration', '3AVG Acceleration', '2AVG Acceleration', '4AVG Strength', '3AVG Strength', '2AVG Strength', '4AVG Agility', '3AVG Agility', '2AVG Agility', '4AVG Awareness', '3AVG Awareness', '2AVG Awareness', '4AVG Catching', '3AVG Catc
# ...

# %%
df.corr()
# Out:
#                        Overall Rating  Unnamed: 1     3Cone  Acceleration  \
# Overall Rating               1.000000   -0.042370  0.034789      0.085026
# Unnamed: 1                  -0.042370    1.000000 -0.040687     -0.132476
# 3Cone                        0.034789   -0.040687  1.000000      0.140780
# Acceleration                 0.085026   -0.132476  0.140780      1.000000
# Agility                      0.096870   -0.060094  0.138446      0.823921
# Awareness                    0.844338   -0.057570 -0.010174     -0.080670
# Ball Carrier Vision          0.037945    0.303679  0.072602      0.657463
# Bench                        0.052164   -0.138077 -0.143202     -0.470715
# Block Shedding               0.091631   -0.851195  0.089818      0.076003
# Broad Jump                  -0.012020   -0.233448  0.113266      0.344588
# Carrying                     0.013952    0.382233  0.075255      0.529346
# Catch In Traffic            -0.006300    0.302583  0.064617      0.550950
# ...

# %%
dfcomb = df[['Overall Rating', 'Position', 'Bench', 'Broad Jump', 'Height', '3Cone', 'Shuttle', 'Awareness', 'Weight', 'Vertical',
            'Vertical/Bench', 'Vertical/Broad Jump', 'Vertical/3Cone', 'Vertical/Shuttle', 'Bench/Broad Jump', 'Bench/3Cone', 
             'Bench/Shuttle', 'Broad Jump/ 3Cone', 
             'Broad Jump/Shuttle', '3Cone/Shuttle']]

# %%
sns.lmplot(x='Overall Rating', y='Awareness', data = dfcomb)

# %%
aware = sns.lmplot(x='Overall Rating', y='Awareness', data = dfcomb)

# %%
aware.savefig('C:\\Users\\tilleymusprime\\Desktop\\aware.png')

# %%
bench = sns.lmplot(x='Overall Rating', y = 'Bench', data=dfcomb)

# %%
bench.savefig('C:\\Users\\tilleymusprime\\Desktop\\bench.png')

# %%
shuttle = sns.lmplot(x='Overall Rating', y='Shuttle', data=dfcomb)

# %%
shuttle.savefig('C:\\Users\\tilleymusprime\\Desktop\\shuttle.png')

# %%
vertical = sns.lmplot(x='Overall Rating', y = 'Vertical', data=dfcomb)

# %%
vertical.savefig('C:\\USers\\tilleymusprime\\Desktop\\vertical.png')

# %%
broad = sns.lmplot(x= 'Overall Rating', y= 'Broad Jump', data=dfcomb)

# %%
broad.savefig('C:\\Users\\tilleymusprime\\Desktop\\broad.png')

# %%
height = sns.lmplot(x='Overall Rating', y='Height', data = dfcomb)

# %%
height.savefig('C:\\Users\\tilleymusprime\\Desktop\\height.png')

# %%
cone3 = sns.lmplot(x= 'Overall Rating', y ='3Cone', data=dfcomb)

# %%
cone3.savefig('C:\\Users\\tilleymusprime\\Desktop\\cone3.png')

# %%
weight = sns.lmplot(x='Overall Rating', y = 'Weight', data=dfcomb)

# %%
weight.savefig('C:\\Users\\tilleymusprime\\Desktop\\weight.png')

# %%
dfcomb.corr()
# Out:
#                      Overall Rating     Bench  Broad Jump    Height     3Cone  \
# Overall Rating             1.000000  0.052164   -0.012020  0.035586  0.034789
# Bench                      0.052164  1.000000   -0.340801 -0.011370 -0.143202
# Broad Jump                -0.012020 -0.340801    1.000000  0.013900  0.113266
# Height                     0.035586 -0.011370    0.013900  1.000000 -0.056347
# 3Cone                      0.034789 -0.143202    0.113266 -0.056347  1.000000
# Shuttle                   -0.022777  0.674896   -0.410682  0.017680 -0.180232
# Awareness                  0.844338  0.094767   -0.014850 -0.009238 -0.010174
# Weight                     0.081946  0.698861   -0.355708  0.035925 -0.184862
# Vertical/Bench            -0.005779 -0.890495    0.358417 -0.011278  0.138618
# Vertical/Broad Jump        0.025225  0.051022   -0.870894 -0.028148 -0.025904
# Vertical/3Cone            -0.019532 -0.229727    0.175051  0.032733 -0.817558
# ...

# %%
dt = dfcomb[dfcomb['Position'] == 'DT']

# %%
dt.corr()
# Out:
#                      Overall Rating     Bench  Broad Jump    Height     3Cone  \
# Overall Rating             1.000000  0.102476    0.042290  0.006416 -0.140248
# Bench                      0.102476  1.000000   -0.018553 -0.135061 -0.007593
# Broad Jump                 0.042290 -0.018553    1.000000 -0.043978 -0.533763
# Height                     0.006416 -0.135061   -0.043978  1.000000  0.127875
# 3Cone                     -0.140248 -0.007593   -0.533763  0.127875  1.000000
# Shuttle                   -0.054968 -0.006785   -0.368890  0.111945  0.662189
# Awareness                  0.897042  0.112015   -0.065652  0.036084 -0.040861
# Weight                     0.201719  0.154847   -0.320802  0.211277  0.328564
# Vertical/Bench            -0.071143 -0.788713    0.342607 -0.016363 -0.206197
# Vertical/Broad Jump        0.040700  0.170641    0.072411 -0.238613 -0.098226
# Vertical/3Cone             0.080139  0.111884    0.656241 -0.214013 -0.595344
# ...

# %%
le = dfcomb[dfcomb['Position'] == 'LE']

# %%
le.corr()
# Out:
#                      Overall Rating     Bench  Broad Jump    Height     3Cone  \
# Overall Rating             1.000000  0.040730   -0.044559  0.043710 -0.130179
# Bench                      0.040730  1.000000   -0.043888 -0.005770  0.099676
# Broad Jump                -0.044559 -0.043888    1.000000  0.161780 -0.462759
# Height                     0.043710 -0.005770    0.161780  1.000000 -0.197284
# 3Cone                     -0.130179  0.099676   -0.462759 -0.197284  1.000000
# Shuttle                   -0.049043  0.038160   -0.470266 -0.111914  0.615082
# Awareness                  0.867683  0.045318   -0.151272  0.048493 -0.102886
# Weight                    -0.000229  0.186265   -0.412893 -0.022573  0.313174
# Vertical/Bench            -0.056116 -0.803988    0.387305  0.003913 -0.302421
# Vertical/Broad Jump        0.035537  0.186855    0.081631 -0.116716 -0.148564
# Vertical/3Cone             0.035805  0.052457    0.707029  0.061876 -0.623811
# ...

# %%
re = dfcomb[dfcomb['Position'] == 'RE']

# %%
re.corr()
# Out:
#                      Overall Rating     Bench  Broad Jump    Height     3Cone  \
# Overall Rating             1.000000 -0.087881   -0.083556  0.384439 -0.190262
# Bench                     -0.087881  1.000000   -0.370918 -0.164417  0.742311
# Broad Jump                -0.083556 -0.370918    1.000000 -0.073046 -0.572430
# Height                     0.384439 -0.164417   -0.073046  1.000000 -0.136587
# 3Cone                     -0.190262  0.742311   -0.572430 -0.136587  1.000000
# Shuttle                   -0.105296  0.672177   -0.659027 -0.028194  0.850715
# Awareness                  0.919914 -0.077954   -0.139604  0.371196 -0.155476
# Weight                     0.323322 -0.068979   -0.244462  0.440140 -0.024426
# Vertical/Bench             0.210773 -0.945745    0.490728  0.240442 -0.825879
# Vertical/Broad Jump       -0.263576 -0.022293    0.605610 -0.332749 -0.248594
# Vertical/3Cone            -0.138688 -0.325038    0.876251 -0.189479 -0.597236
# ...

# %%
scipy.stats.mstats.normaltest()

# %%
dfcomb.head()
# Out:
#    Overall Rating Position  Bench  Broad Jump  Height  3Cone  Shuttle  \
# 0              79       LE   24.0       114.0    79.0    7.4     4.48
# 1              77       LE   28.0       114.0    76.0    7.4     4.48
# 2              67       LE   24.0       114.0    76.0    7.4     4.48
# 3              83       LE   24.0       114.0    77.0    7.4     4.48
# 4              65       LE   30.0       114.0    75.0    7.4     4.48
#
#    Awareness  Weight  Vertical/Bench  Vertical/Broad Jump  Vertical/3Cone  \
# 0         77   300.0        1.333333             0.280702        4.324324
# 1         74   270.0        1.142857             0.280702        4.324324
# 2         55   270.0        1.333333             0.280702        4.324324
# 3         85   336.0        1.333333             0.280702        4.324324
# 4         66   359.0        1.066667             0.280702        4.324324
#
#    Vertical/Shuttle  Bench/Broad Jump  Bench/3Cone  Bench/Shuttle  \
# ...

# %%
cb = dfcomb[dfcomb['Position'] == 'CB']
