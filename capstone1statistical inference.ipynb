# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
from scipy.stats import normaltest

# %%
import seaborn as sns

# %%
df = pd.read_csv('C:\\Users\\tilleymusprime\\Desktop\\mcclean1.csv')

# %%
dfcols = list(df.columns.values)

# %%
print(dfcols)
# Out:
# ['Unnamed: 0', 'Acceleration', 'Agility', 'Awareness', 'Ball Carrier Vision', 'Block Shedding', 'Carrying', 'Catch In Traffic', 'Catching', 'Elusiveness', 'Finesse Moves', 'Hit Power', 'Impact Blocking', 'Injury', 'Juke Move', 'Jumping', 'Man Coverage', 'Name', 'Overall Rating', 'Pass Block', 'Play Action', 'Play Recognition', 'Position', 'Power Moves', 'Press', 'Pursuit', 'Release', 'Route Running', 'Run Block', 'Spectacular Catch', 'Speed', 'Spin Move', 'Stamina', 'Stiff Arm', 'Strength', 'Tackle', 'Team', 'Throw Accuracy Deep', 'Throw Accuracy Mid', 'Throw Accuracy Short', 'Throw Power', 'Throw on the Run', 'Toughness', 'Trucking', 'Zone Coverage', 'Wt', 'Vertical', 'Bench', 'Broad Jump', '3Cone', 'Shuttle', '40yd']

# %%
df.corr()
# Out:
#                       Unnamed: 0  Acceleration   Agility  Awareness  \
# Unnamed: 0              1.000000     -0.149751 -0.049805  -0.112514
# Acceleration           -0.149751      1.000000  0.820494  -0.086847
# Agility                -0.049805      0.820494  1.000000  -0.047109
# Awareness              -0.112514     -0.086847 -0.047109   1.000000
# Ball Carrier Vision    -0.027973      0.659058  0.769401  -0.077659
# Block Shedding         -0.017494      0.083650  0.023870   0.059857
# Carrying                0.051464      0.543467  0.644802  -0.001724
# Catch In Traffic       -0.030991      0.565882  0.653486  -0.072953
# Catching               -0.013655      0.653554  0.746215  -0.003462
# Elusiveness            -0.032178      0.698177  0.813667  -0.058274
# Finesse Moves          -0.018210      0.090191  0.037147   0.030305
# Hit Power              -0.052561      0.087857  0.019309  -0.000585
# Impact Blocking        -0.306181     -0.337953 -0.452173   0.164651
# ...

# %%
dfcomb = df[['Overall Rating', 'Position', 'Bench', 'Broad Jump', '3Cone', 'Shuttle', 'Awareness', 'Wt', 'Vertical']]

# %%
sns.lmplot(x='Overall Rating', y='Awareness', data = dfcomb)

# %%
aware = sns.lmplot(x='Overall Rating', y='Awareness', data = dfcomb)

# %%
bench = sns.lmplot(x='Overall Rating', y = 'Bench', data=dfcomb)

# %%
shuttle = sns.lmplot(x='Overall Rating', y='Shuttle', data=dfcomb)

# %%
vertical = sns.lmplot(x='Overall Rating', y = 'Vertical', data=dfcomb)

# %%
broad = sns.lmplot(x= 'Overall Rating', y= 'Broad Jump', data=dfcomb)

# %%
cone3 = sns.lmplot(x= 'Overall Rating', y ='3Cone', data=dfcomb)

# %%
weight = sns.lmplot(x='Overall Rating', y = 'Wt', data=dfcomb)

# %%
dfcomb.corr()
# Out:
#                 Overall Rating     Bench  Broad Jump     3Cone   Shuttle  \
# Overall Rating        1.000000  0.041360    0.020459 -0.048825 -0.019774
# Bench                 0.041360  1.000000   -0.613461 -0.276894  0.684526
# Broad Jump            0.020459 -0.613461    1.000000  0.277172 -0.849861
# 3Cone                -0.048825 -0.276894    0.277172  1.000000 -0.240177
# Shuttle              -0.019774  0.684526   -0.849861 -0.240177  1.000000
# Awareness             0.833690  0.096257   -0.057892 -0.016052  0.041990
# Wt                    0.005925  0.819566   -0.831806 -0.301547  0.901138
# Vertical              0.030221 -0.570512    0.914901  0.245800 -0.827338
#
#                 Awareness        Wt  Vertical
# Overall Rating   0.833690  0.005925  0.030221
# Bench            0.096257  0.819566 -0.570512
# Broad Jump      -0.057892 -0.831806  0.914901
# 3Cone           -0.016052 -0.301547  0.245800
# Shuttle          0.041990  0.901138 -0.827338
# ...

# %%
dt = dfcomb[dfcomb['Position'] == 'DT']

# %%
dt.corr()
# Out:
#                 Overall Rating     Bench  Broad Jump     3Cone   Shuttle  \
# Overall Rating        1.000000  0.104515    0.042791 -0.157173 -0.109589
# Bench                 0.104515  1.000000   -0.018996 -0.009965 -0.001561
# Broad Jump            0.042791 -0.018996    1.000000 -0.545643 -0.447753
# 3Cone                -0.157173 -0.009965   -0.545643  1.000000  0.651701
# Shuttle              -0.109589 -0.001561   -0.447753  0.651701  1.000000
# Awareness             0.895515  0.114471   -0.066360 -0.066826 -0.097698
# Wt                    0.019559  0.262344   -0.542910  0.551615  0.418875
# Vertical              0.052967  0.128570    0.579819 -0.347134 -0.440322
#
#                 Awareness        Wt  Vertical
# Overall Rating   0.895515  0.019559  0.052967
# Bench            0.114471  0.262344  0.128570
# Broad Jump      -0.066360 -0.542910  0.579819
# 3Cone           -0.066826  0.551615 -0.347134
# Shuttle         -0.097698  0.418875 -0.440322
# ...

# %%
le = dfcomb[dfcomb['Position'] == 'LE']

# %%
le.corr()
# Out:
#                 Overall Rating     Bench  Broad Jump     3Cone   Shuttle  \
# Overall Rating        1.000000  0.041944   -0.045972 -0.131056 -0.048787
# Bench                 0.041944  1.000000   -0.044304  0.098697  0.038926
# Broad Jump           -0.045972 -0.044304    1.000000 -0.463501 -0.469301
# 3Cone                -0.131056  0.098697   -0.463501  1.000000  0.616080
# Shuttle              -0.048787  0.038926   -0.469301  0.616080  1.000000
# Awareness             0.867670  0.048717   -0.155253 -0.103165  0.004342
# Wt                    0.006782  0.268532   -0.674175  0.528119  0.406409
# Vertical             -0.002273  0.105781    0.677774 -0.389944 -0.448183
#
#                 Awareness        Wt  Vertical
# Overall Rating   0.867670  0.006782 -0.002273
# Bench            0.048717  0.268532  0.105781
# Broad Jump      -0.155253 -0.674175  0.677774
# 3Cone           -0.103165  0.528119 -0.389944
# Shuttle          0.004342  0.406409 -0.448183
# ...

# %%
re = dfcomb[dfcomb['Position'] == 'RE']

# %%
re.corr()
# Out:
#                 Overall Rating     Bench  Broad Jump     3Cone   Shuttle  \
# Overall Rating        1.000000  0.157002    0.069879 -0.157052 -0.188769
# Bench                 0.157002  1.000000   -0.067359  0.117239  0.036607
# Broad Jump            0.069879 -0.067359    1.000000 -0.316422 -0.221048
# 3Cone                -0.157052  0.117239   -0.316422  1.000000  0.576386
# Shuttle              -0.188769  0.036607   -0.221048  0.576386  1.000000
# Awareness             0.863251  0.174292   -0.044135 -0.086337 -0.145482
# Wt                   -0.035115  0.508423   -0.374837  0.345772  0.317369
# Vertical              0.124812  0.101872    0.699401 -0.221138 -0.337227
#
#                 Awareness        Wt  Vertical
# Overall Rating   0.863251 -0.035115  0.124812
# Bench            0.174292  0.508423  0.101872
# Broad Jump      -0.044135 -0.374837  0.699401
# 3Cone           -0.086337  0.345772 -0.221138
# Shuttle         -0.145482  0.317369 -0.337227
# ...

# %%
# Out:
#    Overall Rating Position  Bench  Broad Jump  Height  3Cone  Shuttle  \
# 0              79       LE   24.0       114.0    79.0    7.4     4.48
# 1              77       LE   28.0       114.0    76.0    7.4     4.48
# 2              67       LE   24.0       114.0    76.0    7.4     4.48
# 3              83       LE   24.0       114.0    77.0    7.4     4.48
# 4              65       LE   30.0       114.0    75.0    7.4     4.48
#
#    Awareness  Weight  Vertical/Bench  Vertical/Broad Jump  Vertical/3Cone  \
# 0         77   300.0        1.333333             0.280702        4.324324
# 1         74   270.0        1.142857             0.280702        4.324324
# 2         55   270.0        1.333333             0.280702        4.324324
# 3         85   336.0        1.333333             0.280702        4.324324
# 4         66   359.0        1.066667             0.280702        4.324324
#
#    Vertical/Shuttle  Bench/Broad Jump  Bench/3Cone  Bench/Shuttle  \
# ...
